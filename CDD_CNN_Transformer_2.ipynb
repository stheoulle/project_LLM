# %%
# 📓 Notebook : Classification multimodale séquentielle CNN + Transformer

# 📦 Imports
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Dense, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout,
    LayerNormalization, MultiHeadAttention, GlobalAveragePooling1D,
    TimeDistributed, Concatenate, Lambda
)
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.utils.class_weight import compute_class_weight
from PIL import Image
import json
# Out:
# 2025-07-17 11:02:40.642425: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-17 11:02:40.652189: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752742960.663698   56030 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752742960.667709   56030 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752742960.677246   56030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752742960.677264   56030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752742960.677266   56030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752742960.677267   56030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-17 11:02:40.680169: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# --- Dossiers (à adapter)
image_dir_le = 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM'
image_dir_sub = 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Subtracted images of CDD-CESM'
json_dir = 'CDD-CESM/json_output'
excel_path = 'processed_metadata.csv'

# --- Fonction de chargement séquentiel des 8 images (chaque image 224x224x1)
def load_images_sequential(patient_id):
    paths = [
        f"{image_dir_le}/P{patient_id}_L_DM_CC.jpg",
        f"{image_dir_le}/P{patient_id}_L_DM_MLO.jpg",
        f"{image_dir_sub}/P{patient_id}_L_CM_CC.jpg",
        f"{image_dir_sub}/P{patient_id}_L_CM_MLO.jpg",
        f"{image_dir_le}/P{patient_id}_R_DM_CC.jpg",
        f"{image_dir_le}/P{patient_id}_R_DM_MLO.jpg",
        f"{image_dir_sub}/P{patient_id}_R_CM_CC.jpg",
        f"{image_dir_sub}/P{patient_id}_R_CM_MLO.jpg",
    ]
    imgs = []
    for p in paths:
        img = Image.open(p).convert('L').resize((224, 224))
        arr = np.array(img) / 255.0
        arr = arr[..., np.newaxis]  # (224,224,1)
        imgs.append(arr)
    return np.stack(imgs, axis=0)  # (8,224,224,1)

# --- Chargement des métadonnées
meta_df = pd.read_csv(excel_path)
meta_df = meta_df.dropna(subset=['Patient_ID', 'Pathology Classification/ Follow up'])
meta_df['Patient_ID'] = meta_df['Patient_ID'].astype(str)

# --- Chargement textes JSON
texts = []
for pid in meta_df['Patient_ID']:
    path = os.path.join(json_dir, f"P{pid}.json")
    if os.path.exists(path):
        with open(path, encoding="utf-8") as f:
            try:
                d = json.load(f)
                flat_text = []
                for v in d.values():
                    flat_text.extend(map(str, v) if isinstance(v, list) else [str(v)])
                texts.append(" ".join(flat_text))
            except:
                texts.append("")
    else:
        texts.append("")

# %%
# --- Echantillonnage 80%
sampled_df = meta_df.sample(frac=0.8, random_state=42)
sampled_patient_ids = sampled_df['Patient_ID'].tolist()

# %%
# --- Chargement séquentiel des images + labels
images = []
valid_labels = []
valid_pids = []
skipped_image = 0

for pid, label in zip(sampled_df['Patient_ID'], sampled_df['Pathology Classification/ Follow up']):
    try:
        imgs_seq = load_images_sequential(pid)
        images.append(imgs_seq)
        valid_labels.append(label)
        valid_pids.append(pid)
    except Exception as e:
        print(f"Skip patient {pid} due to error: {e}")
        skipped_image += 1
        continue
# Out:
# Skip patient 69 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P69_R_DM_CC.jpg'
# Skip patient 196 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P196_R_DM_CC.jpg'
# Skip patient 47 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P47_L_DM_CC.jpg'
# Skip patient 294 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P294_L_DM_CC.jpg'
# Skip patient 86 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P86_L_DM_MLO.jpg'
# Skip patient 44 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P44_R_DM_MLO.jpg'
# Skip patient 186 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P186_R_DM_MLO.jpg'
# Skip patient 187 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P187_L_DM_MLO.jpg'
# Skip patient 321 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P321_L_DM_CC.jpg'
# Skip patient 56 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P56_L_DM_CC.jpg'
# Skip patient 80 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P80_R_DM_CC.jpg'
# Skip patient 108 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P108_L_DM_MLO.jpg'
# Skip patient 147 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P147_L_DM_CC.jpg'
# Skip patient 321 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P321_L_DM_CC.jpg'
# Skip patient 169 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P169_R_DM_MLO.jpg'
# Skip patient 79 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P79_R_DM_CC.jpg'
# Skip patient 110 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P110_L_DM_CC.jpg'
# Skip patient 229 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P229_L_DM_CC.jpg'
# Skip patient 43 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P43_L_DM_CC.jpg'
# Skip patient 215 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P215_L_DM_MLO.jpg'
# Skip patient 116 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P116_L_DM_CC.jpg'
# Skip patient 57 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P57_L_DM_CC.jpg'
# Skip patient 190 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P190_R_DM_CC.jpg'
# Skip patient 110 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P110_L_DM_CC.jpg'
# Skip patient 38 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P38_L_DM_CC.jpg'
# Skip patient 9 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P9_L_DM_CC.jpg'
# Skip patient 193 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P193_L_DM_CC.jpg'
# Skip patient 58 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P58_L_DM_CC.jpg'
# Skip patient 178 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P178_L_DM_CC.jpg'
# Skip patient 11 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P11_L_DM_CC.jpg'
# Skip patient 245 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P245_L_DM_MLO.jpg'
# Skip patient 187 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P187_L_DM_MLO.jpg'
# Skip patient 153 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P153_R_DM_CC.jpg'
# Skip patient 91 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P91_L_DM_CC.jpg'
# Skip patient 242 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P242_L_DM_MLO.jpg'
# Skip patient 91 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P91_L_DM_CC.jpg'
# Skip patient 69 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P69_R_DM_CC.jpg'
# Skip patient 189 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P189_L_DM_MLO.jpg'
# Skip patient 218 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P218_L_DM_CC.jpg'
# Skip patient 324 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P324_R_DM_CC.jpg'
# Skip patient 29 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P29_L_DM_MLO.jpg'
# Skip patient 223 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P223_R_DM_CC.jpg'
# Skip patient 121 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P121_L_DM_MLO.jpg'
# Skip patient 159 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P159_L_DM_MLO.jpg'
# Skip patient 27 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P27_R_DM_CC.jpg'
# Skip patient 116 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P116_L_DM_CC.jpg'
# Skip patient 139 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P139_L_DM_CC.jpg'
# Skip patient 248 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P248_R_DM_CC.jpg'
# Skip patient 168 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P168_L_DM_CC.jpg'
# Skip patient 153 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P153_R_DM_CC.jpg'
# Skip patient 324 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P324_R_DM_CC.jpg'
# Skip patient 189 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P189_L_DM_MLO.jpg'
# Skip patient 107 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P107_L_DM_MLO.jpg'
# Skip patient 29 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P29_L_DM_MLO.jpg'
# Skip patient 324 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P324_R_DM_CC.jpg'
# Skip patient 241 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P241_L_DM_MLO.jpg'
# Skip patient 60 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P60_L_DM_CC.jpg'
# Skip patient 135 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P135_L_DM_CC.jpg'
# Skip patient 196 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P196_R_DM_CC.jpg'
# Skip patient 217 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P217_R_DM_CC.jpg'
# Skip patient 118 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P118_L_DM_MLO.jpg'
# Skip patient 234 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P234_L_DM_MLO.jpg'
# Skip patient 217 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P217_R_DM_CC.jpg'
# Skip patient 28 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P28_L_DM_CC.jpg'
# Skip patient 104 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P104_L_DM_CC.jpg'
# Skip patient 160 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P160_L_DM_MLO.jpg'
# Skip patient 19 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P19_R_DM_CC.jpg'
# Skip patient 248 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P248_R_DM_CC.jpg'
# Skip patient 44 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P44_R_DM_MLO.jpg'
# Skip patient 134 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P134_L_DM_CC.jpg'
# Skip patient 64 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P64_R_DM_MLO.jpg'
# Skip patient 109 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P109_L_DM_MLO.jpg'
# Skip patient 147 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P147_L_DM_CC.jpg'
# Skip patient 110 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P110_L_DM_CC.jpg'
# Skip patient 7 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P7_L_DM_CC.jpg'
# Skip patient 106 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P106_L_DM_CC.jpg'
# Skip patient 160 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P160_L_DM_MLO.jpg'
# Skip patient 324 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P324_R_DM_CC.jpg'
# Skip patient 106 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P106_L_DM_CC.jpg'
# Skip patient 169 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P169_R_DM_MLO.jpg'
# Skip patient 8 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P8_L_DM_CC.jpg'
# Skip patient 44 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P44_R_DM_MLO.jpg'
# Skip patient 167 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P167_L_DM_CC.jpg'
# Skip patient 34 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P34_L_DM_MLO.jpg'
# Skip patient 231 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P231_L_DM_CC.jpg'
# Skip patient 35 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P35_R_DM_CC.jpg'
# Skip patient 198 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P198_R_DM_CC.jpg'
# Skip patient 53 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P53_L_DM_CC.jpg'
# Skip patient 210 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P210_R_DM_CC.jpg'
# Skip patient 38 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P38_L_DM_CC.jpg'
# Skip patient 208 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P208_L_DM_CC.jpg'
# Skip patient 39 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P39_L_DM_CC.jpg'
# Skip patient 229 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P229_L_DM_CC.jpg'
# Skip patient 4 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P4_L_DM_CC.jpg'
# Skip patient 203 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P203_L_DM_CC.jpg'
# Skip patient 246 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P246_L_DM_CC.jpg'
# Skip patient 142 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P142_L_DM_CC.jpg'
# Skip patient 196 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P196_R_DM_CC.jpg'
# Skip patient 139 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P139_L_DM_CC.jpg'
# Skip patient 210 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P210_R_DM_CC.jpg'
# Skip patient 217 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P217_R_DM_CC.jpg'
# Skip patient 110 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P110_L_DM_CC.jpg'
# Skip patient 107 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P107_L_DM_MLO.jpg'
# Skip patient 151 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P151_L_DM_MLO.jpg'
# Skip patient 190 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P190_R_DM_CC.jpg'
# Skip patient 19 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P19_R_DM_CC.jpg'
# Skip patient 256 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P256_R_DM_CC.jpg'
# Skip patient 80 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P80_R_DM_CC.jpg'
# Skip patient 152 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P152_R_DM_MLO.jpg'
# Skip patient 95 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P95_L_DM_MLO.jpg'
# Skip patient 241 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P241_L_DM_MLO.jpg'
# Skip patient 15 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P15_L_DM_CC.jpg'
# Skip patient 250 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P250_L_DM_MLO.jpg'
# Skip patient 240 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P240_L_DM_CC.jpg'
# Skip patient 41 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P41_L_DM_MLO.jpg'
# Skip patient 245 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P245_L_DM_MLO.jpg'
# Skip patient 167 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P167_L_DM_CC.jpg'
# Skip patient 215 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P215_L_DM_MLO.jpg'
# Skip patient 166 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P166_L_DM_MLO.jpg'
# Skip patient 160 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P160_L_DM_MLO.jpg'
# Skip patient 75 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P75_L_DM_CC.jpg'
# Skip patient 29 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P29_L_DM_MLO.jpg'
# Skip patient 44 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P44_R_DM_MLO.jpg'
# Skip patient 210 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P210_R_DM_CC.jpg'
# Skip patient 157 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P157_L_DM_CC.jpg'
# Skip patient 36 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P36_L_DM_CC.jpg'
# Skip patient 78 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P78_L_DM_MLO.jpg'
# Skip patient 152 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P152_R_DM_MLO.jpg'
# Skip patient 208 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P208_L_DM_CC.jpg'
# Skip patient 50 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P50_L_DM_MLO.jpg'
# Skip patient 222 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P222_L_DM_MLO.jpg'
# Skip patient 41 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P41_L_DM_MLO.jpg'
# Skip patient 294 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P294_L_DM_CC.jpg'
# Skip patient 116 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P116_L_DM_CC.jpg'
# Skip patient 110 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P110_L_DM_CC.jpg'
# Skip patient 39 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P39_L_DM_CC.jpg'
# Skip patient 50 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P50_L_DM_MLO.jpg'
# Skip patient 77 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P77_L_DM_CC.jpg'
# Skip patient 223 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P223_R_DM_CC.jpg'
# Skip patient 72 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P72_L_DM_MLO.jpg'
# Skip patient 50 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P50_L_DM_MLO.jpg'
# Skip patient 136 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P136_L_DM_CC.jpg'
# Skip patient 44 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P44_R_DM_MLO.jpg'
# Skip patient 189 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P189_L_DM_MLO.jpg'
# Skip patient 29 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P29_L_DM_MLO.jpg'
# Skip patient 35 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P35_R_DM_CC.jpg'
# Skip patient 6 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P6_L_DM_CC.jpg'
# Skip patient 196 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P196_R_DM_CC.jpg'
# Skip patient 56 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P56_L_DM_CC.jpg'
# Skip patient 25 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P25_L_DM_CC.jpg'
# Skip patient 17 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P17_L_DM_CC.jpg'
# Skip patient 79 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P79_R_DM_CC.jpg'
# Skip patient 109 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P109_L_DM_MLO.jpg'
# Skip patient 19 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P19_R_DM_CC.jpg'
# Skip patient 80 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P80_R_DM_CC.jpg'
# Skip patient 35 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P35_R_DM_CC.jpg'
# Skip patient 63 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P63_L_DM_CC.jpg'
# Skip patient 256 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P256_R_DM_CC.jpg'
# Skip patient 118 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P118_L_DM_MLO.jpg'
# Skip patient 160 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P160_L_DM_MLO.jpg'
# Skip patient 50 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P50_L_DM_MLO.jpg'
# Skip patient 113 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P113_R_DM_CC.jpg'
# Skip patient 179 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P179_R_DM_CC.jpg'
# Skip patient 248 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P248_R_DM_CC.jpg'
# Skip patient 44 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P44_R_DM_MLO.jpg'
# Skip patient 324 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P324_R_DM_CC.jpg'
# Skip patient 113 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P113_R_DM_CC.jpg'
# Skip patient 86 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P86_L_DM_MLO.jpg'
# Skip patient 108 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P108_L_DM_MLO.jpg'
# Skip patient 201 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P201_L_DM_CC.jpg'
# Skip patient 208 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P208_L_DM_CC.jpg'
# Skip patient 135 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P135_L_DM_CC.jpg'
# Skip patient 117 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P117_L_DM_CC.jpg'
# Skip patient 256 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P256_R_DM_CC.jpg'
# Skip patient 193 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P193_L_DM_CC.jpg'
# Skip patient 169 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P169_R_DM_MLO.jpg'
# Skip patient 7 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P7_L_DM_CC.jpg'
# Skip patient 250 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P250_L_DM_MLO.jpg'
# Skip patient 153 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P153_R_DM_CC.jpg'
# Skip patient 19 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P19_R_DM_CC.jpg'
# Skip patient 112 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P112_L_DM_MLO.jpg'
# Skip patient 107 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P107_L_DM_MLO.jpg'
# Skip patient 175 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P175_L_DM_CC.jpg'
# Skip patient 223 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P223_R_DM_CC.jpg'
# Skip patient 127 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P127_L_DM_CC.jpg'
# Skip patient 38 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P38_L_DM_CC.jpg'
# Skip patient 95 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P95_L_DM_MLO.jpg'
# Skip patient 13 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P13_L_DM_CC.jpg'
# Skip patient 86 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P86_L_DM_MLO.jpg'
# Skip patient 157 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P157_L_DM_CC.jpg'
# Skip patient 190 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P190_R_DM_CC.jpg'
# Skip patient 198 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P198_R_DM_CC.jpg'
# Skip patient 77 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P77_L_DM_CC.jpg'
# Skip patient 248 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P248_R_DM_CC.jpg'
# Skip patient 34 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P34_L_DM_MLO.jpg'
# Skip patient 147 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P147_L_DM_CC.jpg'
# Skip patient 35 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P35_R_DM_CC.jpg'
# Skip patient 15 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P15_L_DM_CC.jpg'
# Skip patient 38 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P38_L_DM_CC.jpg'
# Skip patient 72 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P72_L_DM_MLO.jpg'
# Skip patient 240 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P240_L_DM_CC.jpg'
# Skip patient 28 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P28_L_DM_CC.jpg'
# Skip patient 71 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P71_L_DM_CC.jpg'
# Skip patient 19 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P19_R_DM_CC.jpg'
# Skip patient 11 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P11_L_DM_CC.jpg'
# Skip patient 210 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P210_R_DM_CC.jpg'
# Skip patient 42 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P42_L_DM_CC.jpg'
# Skip patient 169 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P169_R_DM_MLO.jpg'
# Skip patient 6 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P6_L_DM_CC.jpg'
# Skip patient 7 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P7_L_DM_CC.jpg'
# Skip patient 127 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P127_L_DM_CC.jpg'
# Skip patient 43 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P43_L_DM_CC.jpg'
# Skip patient 53 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P53_L_DM_CC.jpg'
# Skip patient 43 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P43_L_DM_CC.jpg'
# Skip patient 256 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P256_R_DM_CC.jpg'
# Skip patient 169 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P169_R_DM_MLO.jpg'
# Skip patient 113 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P113_R_DM_CC.jpg'
# Skip patient 69 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P69_R_DM_CC.jpg'
# Skip patient 11 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P11_L_DM_CC.jpg'
# Skip patient 7 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P7_L_DM_CC.jpg'
# Skip patient 33 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P33_R_DM_CC.jpg'
# Skip patient 86 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P86_L_DM_MLO.jpg'
# Skip patient 224 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P224_L_DM_MLO.jpg'
# Skip patient 190 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P190_R_DM_CC.jpg'
# Skip patient 246 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P246_L_DM_CC.jpg'
# Skip patient 78 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P78_L_DM_MLO.jpg'
# Skip patient 121 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P121_L_DM_MLO.jpg'
# Skip patient 159 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P159_L_DM_MLO.jpg'
# Skip patient 151 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P151_L_DM_MLO.jpg'
# Skip patient 68 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P68_R_DM_CC.jpg'
# Skip patient 58 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P58_L_DM_CC.jpg'
# Skip patient 142 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P142_L_DM_CC.jpg'
# Skip patient 294 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P294_L_DM_CC.jpg'
# Skip patient 242 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P242_L_DM_MLO.jpg'
# Skip patient 27 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P27_R_DM_CC.jpg'
# Skip patient 136 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P136_L_DM_CC.jpg'
# Skip patient 68 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P68_R_DM_CC.jpg'
# Skip patient 147 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P147_L_DM_CC.jpg'
# Skip patient 67 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P67_L_DM_MLO.jpg'
# Skip patient 80 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P80_R_DM_CC.jpg'
# Skip patient 171 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P171_L_DM_CC.jpg'
# Skip patient 56 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P56_L_DM_CC.jpg'
# Skip patient 175 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P175_L_DM_CC.jpg'
# Skip patient 136 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P136_L_DM_CC.jpg'
# Skip patient 137 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P137_L_DM_CC.jpg'
# Skip patient 187 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P187_L_DM_MLO.jpg'
# Skip patient 13 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P13_L_DM_CC.jpg'
# Skip patient 234 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P234_L_DM_MLO.jpg'
# Skip patient 39 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P39_L_DM_CC.jpg'
# Skip patient 20 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P20_L_DM_CC.jpg'
# Skip patient 95 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P95_L_DM_MLO.jpg'
# Skip patient 198 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P198_R_DM_CC.jpg'
# Skip patient 136 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P136_L_DM_CC.jpg'
# Skip patient 186 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P186_R_DM_MLO.jpg'
# Skip patient 113 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P113_R_DM_CC.jpg'
# Skip patient 6 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P6_L_DM_CC.jpg'
# Skip patient 108 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P108_L_DM_MLO.jpg'
# Skip patient 199 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P199_L_DM_CC.jpg'
# Skip patient 152 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P152_R_DM_MLO.jpg'
# Skip patient 106 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P106_L_DM_CC.jpg'
# Skip patient 116 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P116_L_DM_CC.jpg'
# Skip patient 139 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P139_L_DM_CC.jpg'
# Skip patient 26 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P26_R_DM_CC.jpg'
# Skip patient 48 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P48_L_DM_MLO.jpg'
# Skip patient 116 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P116_L_DM_CC.jpg'
# Skip patient 130 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P130_L_DM_MLO.jpg'
# Skip patient 107 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P107_L_DM_MLO.jpg'
# Skip patient 187 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P187_L_DM_MLO.jpg'
# Skip patient 110 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P110_L_DM_CC.jpg'
# Skip patient 28 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P28_L_DM_CC.jpg'
# Skip patient 121 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P121_L_DM_MLO.jpg'
# Skip patient 120 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P120_L_DM_CC.jpg'
# Skip patient 186 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P186_R_DM_MLO.jpg'
# Skip patient 33 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P33_R_DM_CC.jpg'
# Skip patient 67 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P67_L_DM_MLO.jpg'
# Skip patient 247 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P247_L_DM_CC.jpg'
# Skip patient 47 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P47_L_DM_CC.jpg'
# Skip patient 39 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P39_L_DM_CC.jpg'
# Skip patient 118 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P118_L_DM_MLO.jpg'
# Skip patient 36 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P36_L_DM_CC.jpg'
# Skip patient 104 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P104_L_DM_CC.jpg'
# Skip patient 28 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P28_L_DM_CC.jpg'
# Skip patient 112 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P112_L_DM_MLO.jpg'
# Skip patient 208 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P208_L_DM_CC.jpg'
# Skip patient 222 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P222_L_DM_MLO.jpg'
# Skip patient 95 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P95_L_DM_MLO.jpg'
# Skip patient 56 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P56_L_DM_CC.jpg'
# Skip patient 20 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P20_L_DM_CC.jpg'
# Skip patient 136 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P136_L_DM_CC.jpg'
# Skip patient 158 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P158_L_DM_CC.jpg'
# Skip patient 35 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P35_R_DM_CC.jpg'
# Skip patient 248 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P248_R_DM_CC.jpg'
# Skip patient 79 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P79_R_DM_CC.jpg'
# Skip patient 215 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P215_L_DM_MLO.jpg'
# Skip patient 186 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P186_R_DM_MLO.jpg'
# Skip patient 158 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P158_L_DM_CC.jpg'
# Skip patient 42 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P42_L_DM_CC.jpg'
# Skip patient 80 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P80_R_DM_CC.jpg'
# Skip patient 23 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P23_L_DM_CC.jpg'
# Skip patient 22 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P22_L_DM_MLO.jpg'
# Skip patient 108 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P108_L_DM_MLO.jpg'
# Skip patient 120 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P120_L_DM_CC.jpg'
# Skip patient 4 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P4_L_DM_CC.jpg'
# Skip patient 242 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P242_L_DM_MLO.jpg'
# Skip patient 64 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P64_R_DM_MLO.jpg'
# Skip patient 203 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P203_L_DM_CC.jpg'
# Skip patient 152 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P152_R_DM_MLO.jpg'
# Skip patient 64 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P64_R_DM_MLO.jpg'
# Skip patient 245 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P245_L_DM_MLO.jpg'
# Skip patient 179 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P179_R_DM_CC.jpg'
# Skip patient 26 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P26_R_DM_CC.jpg'
# Skip patient 219 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P219_L_DM_CC.jpg'
# Skip patient 204 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P204_L_DM_MLO.jpg'
# Skip patient 215 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P215_L_DM_MLO.jpg'
# Skip patient 6 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P6_L_DM_CC.jpg'
# Skip patient 116 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P116_L_DM_CC.jpg'
# Skip patient 321 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P321_L_DM_CC.jpg'
# Skip patient 190 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P190_R_DM_CC.jpg'
# Skip patient 241 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P241_L_DM_MLO.jpg'
# Skip patient 23 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P23_L_DM_CC.jpg'
# Skip patient 48 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P48_L_DM_MLO.jpg'
# Skip patient 70 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P70_L_DM_MLO.jpg'
# Skip patient 247 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P247_L_DM_CC.jpg'
# Skip patient 70 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P70_L_DM_MLO.jpg'
# Skip patient 35 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P35_R_DM_CC.jpg'
# Skip patient 215 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P215_L_DM_MLO.jpg'
# Skip patient 166 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P166_L_DM_MLO.jpg'
# Skip patient 26 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P26_R_DM_CC.jpg'
# Skip patient 231 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P231_L_DM_CC.jpg'
# Skip patient 118 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P118_L_DM_MLO.jpg'
# Skip patient 168 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P168_L_DM_CC.jpg'
# Skip patient 113 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P113_R_DM_CC.jpg'
# Skip patient 20 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P20_L_DM_CC.jpg'
# Skip patient 20 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P20_L_DM_CC.jpg'
# Skip patient 242 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P242_L_DM_MLO.jpg'
# Skip patient 152 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P152_R_DM_MLO.jpg'
# Skip patient 29 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P29_L_DM_MLO.jpg'
# Skip patient 25 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P25_L_DM_CC.jpg'
# Skip patient 221 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P221_L_DM_MLO.jpg'
# Skip patient 153 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P153_R_DM_CC.jpg'
# Skip patient 133 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P133_L_DM_CC.jpg'
# Skip patient 34 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P34_L_DM_MLO.jpg'
# Skip patient 57 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P57_L_DM_CC.jpg'
# Skip patient 67 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P67_L_DM_MLO.jpg'
# Skip patient 26 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P26_R_DM_CC.jpg'
# Skip patient 178 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P178_L_DM_CC.jpg'
# Skip patient 1 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P1_L_DM_CC.jpg'
# Skip patient 321 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P321_L_DM_CC.jpg'
# Skip patient 118 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P118_L_DM_MLO.jpg'
# Skip patient 118 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P118_L_DM_MLO.jpg'
# Skip patient 204 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P204_L_DM_MLO.jpg'
# Skip patient 203 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P203_L_DM_CC.jpg'
# Skip patient 106 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P106_L_DM_CC.jpg'
# Skip patient 223 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P223_R_DM_CC.jpg'
# Skip patient 9 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P9_L_DM_CC.jpg'
# Skip patient 56 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P56_L_DM_CC.jpg'
# Skip patient 142 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P142_L_DM_CC.jpg'
# Skip patient 7 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P7_L_DM_CC.jpg'
# Skip patient 107 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P107_L_DM_MLO.jpg'
# Skip patient 203 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P203_L_DM_CC.jpg'
# Skip patient 182 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P182_L_DM_CC.jpg'
# Skip patient 104 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P104_L_DM_CC.jpg'
# Skip patient 68 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P68_R_DM_CC.jpg'
# Skip patient 248 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P248_R_DM_CC.jpg'
# Skip patient 186 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P186_R_DM_MLO.jpg'
# Skip patient 179 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P179_R_DM_CC.jpg'
# Skip patient 199 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P199_L_DM_CC.jpg'
# Skip patient 190 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P190_R_DM_CC.jpg'
# Skip patient 56 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P56_L_DM_CC.jpg'
# Skip patient 196 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P196_R_DM_CC.jpg'
# Skip patient 72 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P72_L_DM_MLO.jpg'
# Skip patient 205 due to error: [Errno 2] No such file or directory: 'CDD-CESM/PKG - CDD-CESM/CDD-CESM/Low energy images of CDD-CESM/P205_L_DM_CC.jpg'

# %%
# --- Alignement des données
image_patient_ids = set(valid_pids)
text_patient_ids = set(sampled_patient_ids)
metadata_patient_ids = set(meta_df['Patient_ID'])
common_patient_ids = list(image_patient_ids & text_patient_ids & metadata_patient_ids)

image_dict = {pid: img for pid, img in zip(valid_pids, images) if pid in common_patient_ids}
label_dict = {pid: label for pid, label in zip(valid_pids, valid_labels) if pid in common_patient_ids}
text_dict = {pid: text for pid, text in zip(sampled_patient_ids, texts) if pid in common_patient_ids}
meta_dict = {pid: meta_df[meta_df['Patient_ID'] == pid].iloc[0] for pid in common_patient_ids}

images_filtered = np.array([image_dict[pid] for pid in common_patient_ids])  # shape (N, 8, 224, 224, 1)
labels_filtered = [label_dict[pid] for pid in common_patient_ids]
texts_filtered = [text_dict[pid] for pid in common_patient_ids]
meta_df_filtered = pd.DataFrame([meta_dict[pid] for pid in common_patient_ids])

# %%
# --- Textes vectorisés
vectorizer = TfidfVectorizer(max_features=1000)
text_features_filtered = vectorizer.fit_transform(texts_filtered).toarray()

# %%
# --- Encodage des métadonnées
numerical = meta_df_filtered.select_dtypes(include=['float', 'int']).columns.tolist()
categorical = meta_df_filtered.select_dtypes(include=['object']).drop(columns=['Patient_ID', 'Pathology Classification/ Follow up']).columns.tolist()

scaler = StandardScaler()
encoder = OneHotEncoder(sparse_output=False)

meta_num_filtered = scaler.fit_transform(meta_df_filtered[numerical])
meta_cat_filtered = encoder.fit_transform(meta_df_filtered[categorical])
meta_features_filtered = np.concatenate([meta_num_filtered, meta_cat_filtered], axis=1)

# --- Encodage des labels
valid_labels_encoded, label_names = pd.factorize(labels_filtered)
labels_cat = to_categorical(valid_labels_encoded)

# --- Poids de classes
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(valid_labels_encoded), y=valid_labels_encoded)
class_weight_dict = dict(enumerate(class_weights))
# Out:
# /tmp/ipykernel_56030/1470660569.py:13: FutureWarning: factorize with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   valid_labels_encoded, label_names = pd.factorize(labels_filtered)

# %%
# --- Split train/test
X_img_temp, X_img_test, X_meta_temp, X_meta_test, X_txt_temp, X_txt_test, y_temp, y_test = train_test_split(
    images_filtered, meta_features_filtered, text_features_filtered, labels_cat,
    test_size=0.1, random_state=42)

X_img_train, X_img_val, X_meta_train, X_meta_val, X_txt_train, X_txt_val, y_train, y_val = train_test_split(
    X_img_temp, X_meta_temp, X_txt_temp, y_temp,
    test_size=0.2, random_state=42)

# %%
# --- Transformer block
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super().__init__()
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu"),
            Dense(embed_dim)
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training=None):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
# --- Modèle séquentiel CNN + Transformer multimodal
# Inputs
img_seq_input = Input(shape=(8, 224, 224, 1), name='img_seq_input')
meta_input = Input(shape=(meta_features_filtered.shape[1],), name='meta_input')
text_input = Input(shape=(text_features_filtered.shape[1],), name='text_input')

# CNN partagé pour extraire features de chaque image
def create_cnn_encoder():
    inputs = Input(shape=(224, 224, 1))
    x = Conv2D(32, (3,3), activation='relu')(inputs)
    x = MaxPooling2D()(x)
    x = Conv2D(64, (3,3), activation='relu')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(64, activation='relu')(x)
    return Model(inputs, x, name='cnn_encoder')

cnn_encoder = create_cnn_encoder()
# Out:
# 2025-07-17 11:08:33.470319: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
# Appliquer le CNN en TimeDistributed sur les 8 images
x_img_seq = TimeDistributed(cnn_encoder)(img_seq_input)  # (batch, 8, 64)

# Transformer sur séquence d'images
x_img_seq = TransformerBlock(embed_dim=64, num_heads=4, ff_dim=128)(x_img_seq)  # (batch, 8, 64)
x_img_seq = GlobalAveragePooling1D()(x_img_seq)  # (batch, 64)

# %%
# Fusion multimodale : concat images + métadonnées + texte
x = Concatenate()([x_img_seq, meta_input, text_input])
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.3)(x)
outputs = Dense(len(label_names), activation='softmax')(x)

model = Model(inputs=[img_seq_input, meta_input, text_input], outputs=outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ img_seq_input       │ (None, 8, 224,    │          0 │ -                 │
# │ (InputLayer)        │ 224, 1)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, 8, 64)     │     22,976 │ img_seq_input[0]… │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_block   │ (None, 8, 64)     │     83,200 │ time_distributed… │
# │ (TransformerBlock)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ transformer_bloc… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ meta_input          │ (None, 381)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ text_input          │ (None, 272)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 717)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ meta_input[0][0], │
# │                     │                   │            │ text_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     91,904 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      8,256 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 3)         │        195 │ dropout_4[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 206,531 (806.76 KB)
#  Trainable params: 206,531 (806.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# --- Entraînement
history = model.fit(
    [X_img_train, X_meta_train, X_txt_train], y_train,
    validation_data=([X_img_val, X_meta_val, X_txt_val], y_val),
    epochs=30,
    batch_size=16,
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.3279 - loss: 1.1496 - val_accuracy: 0.2000 - val_loss: 1.1122
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.2920 - loss: 1.1450 - val_accuracy: 0.3143 - val_loss: 1.1147
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.3531 - loss: 1.0879 - val_accuracy: 0.2286 - val_loss: 1.0918
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.3485 - loss: 1.0938 - val_accuracy: 0.3429 - val_loss: 1.1147
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.3451 - loss: 1.0907 - val_accuracy: 0.3429 - val_loss: 1.1035
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.4004 - loss: 1.0369 - val_accuracy: 0.3714 - val_loss: 1.0809
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.4015 - loss: 1.0721 - val_accuracy: 0.5714 - val_loss: 1.0495
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.3412 - loss: 1.0916 - val_accuracy: 0.6000 - val_loss: 1.0526
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.5734 - loss: 0.9899 - val_accuracy: 0.5143 - val_loss: 1.0167
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.4918 - loss: 1.0345 - val_accuracy: 0.5143 - val_loss: 1.0430
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.5093 - loss: 1.0300 - val_accuracy: 0.5143 - val_loss: 1.0483
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.6088 - loss: 0.9762 - val_accuracy: 0.5429 - val_loss: 1.0418
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.4624 - loss: 1.0342 - val_accuracy: 0.5429 - val_loss: 1.0560
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.5237 - loss: 0.9861 - val_accuracy: 0.2857 - val_loss: 1.1205
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5082 - loss: 1.0198 - val_accuracy: 0.5714 - val_loss: 1.0477
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5523 - loss: 0.9054 - val_accuracy: 0.5143 - val_loss: 1.0720
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.5847 - loss: 0.9101 - val_accuracy: 0.5429 - val_loss: 1.0420
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5936 - loss: 0.8613 - val_accuracy: 0.5143 - val_loss: 1.0135
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6931 - loss: 0.8271 - val_accuracy: 0.5429 - val_loss: 1.0542
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.5730 - loss: 0.8392 - val_accuracy: 0.5143 - val_loss: 1.0606
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.7495 - loss: 0.7267 - val_accuracy: 0.5429 - val_loss: 1.0702
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.6934 - loss: 0.7637 - val_accuracy: 0.5714 - val_loss: 1.0214
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.7682 - loss: 0.6500 - val_accuracy: 0.6000 - val_loss: 1.0626
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.7057 - loss: 0.6797 - val_accuracy: 0.5429 - val_loss: 1.0678
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8103 - loss: 0.5742 - val_accuracy: 0.5714 - val_loss: 1.0891
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.7444 - loss: 0.5789 - val_accuracy: 0.4571 - val_loss: 1.1619
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8494 - loss: 0.5224 - val_accuracy: 0.5714 - val_loss: 1.0953
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8611 - loss: 0.5046 - val_accuracy: 0.4571 - val_loss: 1.1322
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.8829 - loss: 0.4194 - val_accuracy: 0.5429 - val_loss: 1.2072
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8330 - loss: 0.4170 - val_accuracy: 0.5429 - val_loss: 1.1515

# %%
# --- Évaluation sur test
# Prédictions
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

y_pred_proba = model.predict([X_img_test, X_meta_test, X_txt_test])
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test, axis=1)

# Rapport de classification
print(classification_report(y_true, y_pred, target_names=label_names))
print("F1-score (weighted):", f1_score(y_true, y_pred, average='weighted'))
print("Accuracy:", accuracy_score(y_true, y_pred))

test_loss, test_acc = model.evaluate([X_img_test, X_meta_test, X_txt_test], y_test)
print(f"Test accuracy: {test_acc:.4f}")

# confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = model.predict([X_img_test, X_meta_test, X_txt_test])
y_pred_classes = np.argmax(y_pred, axis=1)
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_names)
disp.plot(cmap='Blues')
import matplotlib.pyplot as plt
plt.title('Confusion Matrix')
plt.show()

# Roc- AUC

from sklearn.metrics import roc_auc_score
y_pred_proba = model.predict([X_img_test, X_meta_test, X_txt_test])
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
print(f"ROC AUC Score: {roc_auc:.4f}")


# loss and accuracy curves

import matplotlib.pyplot as plt
def plot_history(history):
    plt.figure(figsize=(12, 5))
    
    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

plot_history(history)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
#               precision    recall  f1-score   support
#
#    Malignant       0.44      0.67      0.53         6
#       Benign       0.67      0.33      0.44         6
#       Normal       0.62      0.62      0.62         8
#
#     accuracy                           0.55        20
#    macro avg       0.58      0.54      0.53        20
# weighted avg       0.58      0.55      0.54        20
#
# F1-score (weighted): 0.5433333333333333
# Accuracy: 0.55
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.5500 - loss: 1.1297
# Test accuracy: 0.5500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# ROC AUC Score: 0.6756

# %%
Update le code pour que l'on garde le patient s'il y a au moins une image valide, même si les autres sont manquantes.
# --- Chargement séquentiel des images + labels avec validation partielle
images = []
valid_labels = []
valid_pids = []
skipped_image = 0
for pid, label in zip(sampled_df['Patient_ID'], sampled_df['Pathology Classification/ Follow up']):
    try:
        imgs_seq = load_images_sequential(pid)
        if imgs_seq.shape[0] > 0:  # Vérifie s'il y a au moins une image valide
            images.append(imgs_seq)
            valid_labels.append(label)
            valid_pids.append(pid)
    except Exception as e:
        print(f"Skip patient {pid} due to error: {e}")
        skipped_image += 1
        continue
